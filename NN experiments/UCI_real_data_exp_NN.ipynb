# %%
import matplotlib.pyplot as plt
import numpy as np 
from UCI_utils import *
from collections import Counter
from imblearn.datasets import fetch_datasets
from sklearn.model_selection import train_test_split

# %%
yeast_me2 = fetch_datasets()['yeast_me2']
df_feature = yeast_me2.data
df_target = yeast_me2.target
#turn all the -1 to 0
df_target[df_target == -1] = 0

# %%
alpha_list = [0.001,0.0011,0.0012,0.0013,0.0014,0.0015]
log_loss_custom,\
log_loss_crossentropy,\
log_loss_custom_std,\
log_loss_crossentropy_std= experiment_NN_yeast_me2(alpha_list, df_feature, df_target)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2024-08-13 13:39:31.291866: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 10/10 [==============================] - 0s 433us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 10/10 [==============================] - 0s 400us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 10/10 [==============================] - 0s 435us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 10/10 [==============================] - 0s 389us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# ...

# %%
abalone_19 = fetch_datasets()['abalone_19']
df_feature = abalone_19.data
df_target = abalone_19.target
#turn all the -1 to 0
df_target[df_target == -1] = 0

# %%
alpha_list = [0.0001,0.0002,0.0003,0.0004,0.0005]
log_loss_custom,\
log_loss_crossentropy,\
_,_= experiment_NN_abalone_19(alpha_list, df_feature, df_target)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 27/27 [==============================] - 0s 332us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 27/27 [==============================] - 0s 596us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 27/27 [==============================] - 0s 302us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 27/27 [==============================] - 0s 290us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 27/27 [==============================] - 0s 294us/step
# ...

# %%
yeast_me2 = fetch_datasets()['ecoli']
df_feature = yeast_me2.data
df_target = yeast_me2.target
#turn all the -1 to 0
df_target[df_target == -1] = 0


alpha_list = [0.009,0.0095,0.001,0.0015,0.002]
log_loss_custom,\
log_loss_crossentropy,\
_,_= experiment_NN_ecoli(alpha_list, df_feature, df_target)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 3/3 [==============================] - 0s 749us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 3/3 [==============================] - 0s 735us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 3/3 [==============================] - 0s 697us/step
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# ...
