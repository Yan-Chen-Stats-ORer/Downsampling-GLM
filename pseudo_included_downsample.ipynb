# %%
import matplotlib.pyplot as plt
import numpy as np 
from new_utils_downsample import *

# %% [markdown]
# $\tau_n=11.0,\theta_1=0.5$

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p98 = 1/(1+np.exp(9.8+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p98))
# Out:
# Prob(Y=1) 4.364651759227631e-05

# %%
alpha_list98 = [3e-5,3e-5,4e-5,5e-5,6e-5,7e-5]

MSE_pseudo_MLE_list98,std_SE_pseudo_MLE_list98,\
MSE_cond_MLE_list98,std_SE_cond_MLE_list98,\
MSE_inverse_list98,std_SE_inverse_list98,\
mean_diff_SE_inverse_pseudo_list98,std_diff_SE_inverse_pseudo_list98,\
mean_diff_SE_cond_pseudo_list98,std_diff_SE_cond_pseudo_list98 = experiment_logit(9.8,alpha_list98,exp_num=500)

plot_results_all(MSE_pseudo_MLE_list98,std_SE_pseudo_MLE_list98,
                MSE_cond_MLE_list98,std_SE_cond_MLE_list98,
                MSE_inverse_list98,std_SE_inverse_list98,
                mean_diff_SE_inverse_pseudo_list98,std_diff_SE_inverse_pseudo_list98,
                mean_diff_SE_cond_pseudo_list98,std_diff_SE_cond_pseudo_list98,
                alpha_list98,9.8,np.mean(p98),exp_num = 500)
# Out:
# Prob(Y=1) 4.363016276298253e-05

# %% [markdown]
# $\tau_n=10.0,\theta_1=0.5$

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p10 = 1/(1+np.exp(10.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p10))
# Out:
# Prob(Y=1) 3.5721841601624124e-05

# %%
alpha_list10 = [3.55e-5,3.56e-5,3.57e-5,3.58e-5,3.59e-5,3.6e-5]

MSE_pseudo_MLE_list10,std_SE_pseudo_MLE_list10,\
MSE_cond_MLE_list10,std_SE_cond_MLE_list10,\
MSE_inverse_list10,std_SE_inverse_list10,\
mean_diff_SE_inverse_pseudo_list10,std_diff_SE_inverse_pseudo_list10,\
mean_diff_SE_cond_pseudo_list10,std_diff_SE_cond_pseudo_list10 = experiment_logit(10,alpha_list10,exp_num=500)

plot_results_all(MSE_pseudo_MLE_list10,std_SE_pseudo_MLE_list10,
                MSE_cond_MLE_list10,std_SE_cond_MLE_list10,
                MSE_inverse_list10,std_SE_inverse_list10,
                mean_diff_SE_inverse_pseudo_list10,std_diff_SE_inverse_pseudo_list10,
                mean_diff_SE_cond_pseudo_list10,std_diff_SE_cond_pseudo_list10,
                alpha_list10,10.0,np.mean(p10),exp_num = 500)
# Out:
# Prob(Y=1) 3.57266400472793e-05

# %% [markdown]
# theta_0 = 9.0, theta_1=0.5

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p9 = 1/(1+np.exp(9.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p9))
# Out:
# Prob(Y=1) 9.712908027847581e-05

# %%
alpha_list9 = [9.4e-5,9.5e-5,9.6e-5,9.7e-5,9.8e-5,9.9e-5]

MSE_pseudo_MLE_list9,std_SE_pseudo_MLE_list9,\
MSE_cond_MLE_list9,std_SE_cond_MLE_list9,\
MSE_inverse_list9,std_SE_inverse_list9,\
mean_diff_SE_inverse_pseudo_list9,std_diff_SE_inverse_pseudo_list9,\
mean_diff_SE_cond_pseudo_list9,std_diff_SE_cond_pseudo_list9 = experiment_logit(9.0,alpha_list9,exp_num=500)

plot_results_all(MSE_pseudo_MLE_list9,std_SE_pseudo_MLE_list9,
                MSE_cond_MLE_list9,std_SE_cond_MLE_list9,
                MSE_inverse_list9,std_SE_inverse_list9,
                mean_diff_SE_inverse_pseudo_list9,std_diff_SE_inverse_pseudo_list9,
                mean_diff_SE_cond_pseudo_list9,std_diff_SE_cond_pseudo_list9,
                alpha_list9,9.0,np.mean(p9),exp_num = 500)
# Out:
# Prob(Y=1) 9.713223634497208e-05

# %%
plot_results_all(MSE_pseudo_MLE_list9,std_SE_pseudo_MLE_list9,
                MSE_cond_MLE_list9,std_SE_cond_MLE_list9,
                MSE_inverse_list9,std_SE_inverse_list9,
                mean_diff_SE_inverse_pseudo_list9,std_diff_SE_inverse_pseudo_list9,
                mean_diff_SE_cond_pseudo_list9,std_diff_SE_cond_pseudo_list9,
                alpha_list9,9.0,np.mean(p9),exp_num = 500)

# %% [markdown]
# $\tau_n=8.0$, $\theta_1=0.5$

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p8 = 1/(1+np.exp(8.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p8))
# Out:
# Prob(Y=1) 0.0002639183573601383

# %%
alpha_list8 = [2.6e-4,2.61e-4,2.62e-4,2.63e-4,2.64e-4,2.65e-4]

MSE_pseudo_MLE_list8,std_SE_pseudo_MLE_list8,\
MSE_cond_MLE_list8,std_SE_cond_MLE_list8,\
MSE_inverse_list8,std_SE_inverse_list8,\
mean_diff_SE_inverse_pseudo_list8,std_diff_SE_inverse_pseudo_list8,\
mean_diff_SE_cond_pseudo_list8,std_diff_SE_cond_pseudo_list8 = experiment_logit(8.0,alpha_list8,exp_num=500)
# Out:
# Prob(Y=1) 0.0002638435314743338

# %%
plot_results_all(MSE_pseudo_MLE_list8,std_SE_pseudo_MLE_list8,
                MSE_cond_MLE_list8,std_SE_cond_MLE_list8,
                MSE_inverse_list8,std_SE_inverse_list8,
                mean_diff_SE_inverse_pseudo_list8,std_diff_SE_inverse_pseudo_list8,
                mean_diff_SE_cond_pseudo_list8,std_diff_SE_cond_pseudo_list8,
                alpha_list8,8.0,np.mean(p8),exp_num = 500)

# %% [markdown]
# theta_0 = 7.0, theta_1=0.5

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p7 = 1/(1+np.exp(7.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p7))
# Out:
# Prob(Y=1) 0.0007170316813783941

# %%
alpha_list7 = [6.9e-4,7.0e-4,7.1e-4,7.2e-4,7.3e-4,7.4e-4]

MSE_pseudo_MLE_list7,std_SE_pseudo_MLE_list7,\
MSE_cond_MLE_list7,std_SE_cond_MLE_list7,\
MSE_inverse_list7,std_SE_inverse_list7,\
mean_diff_SE_inverse_pseudo_list7,std_diff_SE_inverse_pseudo_list7,\
mean_diff_SE_cond_pseudo_list7,std_diff_SE_cond_pseudo_list7 = experiment_logit(7.0,alpha_list7,exp_num=500)
# Out:
# Prob(Y=1) 0.0007168858506831374

# %%
plot_results_all(MSE_pseudo_MLE_list7,std_SE_pseudo_MLE_list7,
                MSE_cond_MLE_list7,std_SE_cond_MLE_list7,
                MSE_inverse_list7,std_SE_inverse_list7,
                mean_diff_SE_inverse_pseudo_list7,std_diff_SE_inverse_pseudo_list7,
                mean_diff_SE_cond_pseudo_list7,std_diff_SE_cond_pseudo_list7,
                alpha_list7,7.0,np.mean(p7),exp_num = 500)

# %% [markdown]
# theta_0 = 6.0, theta_1 = 0.5

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p6 = 1/(1+np.exp(6.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p6))
# Out:
# Prob(Y=1) 0.0019472050263844003

# %%
alpha_list6 = [1.91e-3,1.92e-3,1.93e-3,1.94e-3,1.95e-3,1.96e-3]

MSE_pseudo_MLE_list6,std_SE_pseudo_MLE_list6,\
MSE_cond_MLE_list6,std_SE_cond_MLE_list6,\
MSE_inverse_list6,std_SE_inverse_list6,\
mean_diff_SE_inverse_pseudo_list6,std_diff_SE_inverse_pseudo_list6,\
mean_diff_SE_cond_pseudo_list6,std_diff_SE_cond_pseudo_list6 = experiment_logit(6.0,alpha_list6,exp_num=500)
# Out:
# Prob(Y=1) 0.0019461806342787919

# %%
plot_results_all(MSE_pseudo_MLE_list6,std_SE_pseudo_MLE_list6,
                MSE_cond_MLE_list6,std_SE_cond_MLE_list6,
                MSE_inverse_list6,std_SE_inverse_list6,
                mean_diff_SE_inverse_pseudo_list6,std_diff_SE_inverse_pseudo_list6,
                mean_diff_SE_cond_pseudo_list6,std_diff_SE_cond_pseudo_list6,
                alpha_list6,6.0,np.mean(p6),exp_num = 500)

# %% [markdown]
# $\tau_n=5.0, \theta_1=0.5$

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p5 = 1/(1+np.exp(5.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p5))
# Out:
# Prob(Y=1) 0.005275191677371496

# %%
alpha_list5 = [5.25e-3,5.26e-3,5.27e-3,5.28e-3,5.29e-3,5.30e-3]

MSE_pseudo_MLE_list5,std_SE_pseudo_MLE_list5,\
MSE_cond_MLE_list5,std_SE_cond_MLE_list5,\
MSE_inverse_list5,std_SE_inverse_list5,\
mean_diff_SE_inverse_pseudo_list5,std_diff_SE_inverse_pseudo_list5,\
mean_diff_SE_cond_pseudo_list5,std_diff_SE_cond_pseudo_list5 = experiment_logit(5.0,alpha_list5,exp_num=1000)
# Out:
# Prob(Y=1) 0.005273217811681133

# %%
plot_results_all(MSE_pseudo_MLE_list5,std_SE_pseudo_MLE_list5,
                MSE_cond_MLE_list5,std_SE_cond_MLE_list5,
                MSE_inverse_list5,std_SE_inverse_list5,
                mean_diff_SE_inverse_pseudo_list5,std_diff_SE_inverse_pseudo_list5,
                mean_diff_SE_cond_pseudo_list5,std_diff_SE_cond_pseudo_list5,
                alpha_list5,5.0,np.mean(p5),exp_num = 1000)

# %% [markdown]
# $\tau_n=1.0,\theta_1=0.5$

# %%
n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p1 = 1/(1+np.exp(1.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p1))

n = pow(10,6)
X = np.random.uniform(low=0.0,high=1.0,size=n)
p2 = 1/(1+np.exp(2.0+np.dot(0.5,X)))
print('Prob(Y=1)',np.mean(p2))
# Out:
# Prob(Y=1) 0.2236874797075366
# Prob(Y=1) 0.09605404747138255

# %%
alpha_list1 = [0.221,0.222,0.223,0.224,0.225,0.226]

MSE_pseudo_MLE_list1,std_SE_pseudo_MLE_list1,\
MSE_cond_MLE_list1,std_SE_cond_MLE_list1,\
MSE_inverse_list1,std_SE_inverse_list1,\
mean_diff_SE_inverse_pseudo_list1,std_diff_SE_inverse_pseudo_list1,\
mean_diff_SE_cond_pseudo_list1,std_diff_SE_cond_pseudo_list1 = experiment_logit(1.0,alpha_list1,exp_num=500)
# Out:
# Prob(Y=1) 0.2236799291605406

# %%
plot_results_all(MSE_pseudo_MLE_list1,std_SE_pseudo_MLE_list1,
                MSE_cond_MLE_list1,std_SE_cond_MLE_list1,
                MSE_inverse_list1,std_SE_inverse_list1,
                mean_diff_SE_inverse_pseudo_list1,std_diff_SE_inverse_pseudo_list1,
                mean_diff_SE_cond_pseudo_list1,std_diff_SE_cond_pseudo_list1,
                alpha_list1,1.0,np.mean(p1),exp_num = 500)

# %%
alpha_list2 = [0.093,0.094,0.095,0.096,0.097,0.098]

MSE_pseudo_MLE_list2,std_SE_pseudo_MLE_list2,\
MSE_cond_MLE_list2,std_SE_cond_MLE_list2,\
MSE_inverse_list2,std_SE_inverse_list2,\
mean_diff_SE_inverse_pseudo_list2,std_diff_SE_inverse_pseudo_list2,\
mean_diff_SE_cond_pseudo_list2,std_diff_SE_cond_pseudo_list2 = experiment_logit(2.0,alpha_list2,exp_num=500)

plot_results_all(MSE_pseudo_MLE_list2,std_SE_pseudo_MLE_list2,
                MSE_cond_MLE_list2,std_SE_cond_MLE_list2,
                MSE_inverse_list2,std_SE_inverse_list2,
                mean_diff_SE_inverse_pseudo_list2,std_diff_SE_inverse_pseudo_list2,
                mean_diff_SE_cond_pseudo_list2,std_diff_SE_cond_pseudo_list2,
                alpha_list2,2.0,np.mean(p2),exp_num = 500)
# Out:
# Prob(Y=1) 0.0960801620970388
